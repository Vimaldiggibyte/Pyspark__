# %%
# %run /Workspace/Git folder/Pyspark__/src/employee_utils.py

# %%
employee_data = [
    (101, "rahul", 60000),
    (102, "priya", 45000),
    (103, "arjun", 70000),
    (104, "sneha", 55000)
]

employee_df = spark.createDataFrame(
    employee_data,
    ["EmployeeID", "EmployeeName", "Salary"]
)

employee_df.show()

# %%
employee_df = clean_names(employee_df)

employee_df = filter_salary(employee_df)

employee_df = calculate_bonus(employee_df)

employee_df.show()
